# %%
name=input("Your Name:- ")
print("welcome ",name)
n1=int(input("Enter your 1st number:- "))
n2=int(input("Enter your 2nd number:- "))
ans=n1*n2
print("The answer to your query is ",ans)
print("THANK YOU",name)
# Out:
# welcome  RAM
# The answer to your query is  408
# THANK YOU RAM
