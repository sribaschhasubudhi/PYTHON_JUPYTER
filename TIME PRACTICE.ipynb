# %%
import time

# %%
current_time=time.time()
print(f"{current_time} seconds passed since 1 January 1970")
# Out:
# 1784992943.411496 seconds passed since 1 January 1970

# %%
n=0
for i in range(2):
    print("start")
    n=n+0.5
    #time.sleep(30)
    print(f"{n} minute")
# Out:
# start
# 0.5 minute
# start
# 1.0 minute

# %%
current=time.localtime()
print(current)
# Out:
# time.struct_time(tm_year=2026, tm_mon=7, tm_mday=25, tm_hour=20, tm_min=52, tm_sec=23, tm_wday=5, tm_yday=206, tm_isdst=0)

# %%
print(time.strftime(f"%d/%m/%Y"))
print(time.strftime(f"Market closes at %H:%M:%S"))
#print(time.sleep(1))                   # Returns None
alarm=time.strftime("%I:%M %p")
print(f"Ting Tong! It's {alarm}")
# Out:
# 25/07/2026
# Market closes at 20:52:57
# Ting Tong! It's 08:52 PM
