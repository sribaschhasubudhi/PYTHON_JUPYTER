# %%
import pandas as pd
import numpy as np
from io import StringIO

# %%
book_datj={"Book":"Deep Work",
          "Author":"Cal Newport",
          "Details":{"pages":304,
                      "cover type":"Papertype",
                      "ISBN":9781455586691}
        }

# %%
pd.json_normalize(book_datj)
# Out:
#         Book       Author  Details.pages Details.cover type   Details.ISBN
# 0  Deep Work  Cal Newport            304          Papertype  9781455586691

# %%
att_dtj=[{"Section":"A",
        "students":["John","Adam","Rick"],
        "attendance":{"John":"Present",
                      "Adam":"Absent",
                      "Rick":"Absent"}},
        {"Section":"B",
        "students":["Bill","Jane","Kenny"],
        "attendance":
                {"Bill":"Present",
                 "Jane":"Absent",
                 "Kenny":"Present"}},
        {"Section":"C",
        "students":["Walton","Isabel","Lili"],
        "attendance":
                {"Walton":"Present",
                 "Isabel":"Absent",
                 "Lili":"Present"}}]

# %%
pd.json_normalize(att_dtj,sep=" of ")
# Out:
#   Section                students attendance of John attendance of Adam  \
# 0       A      [John, Adam, Rick]            Present             Absent
# 1       B     [Bill, Jane, Kenny]                NaN                NaN
# 2       C  [Walton, Isabel, Lili]                NaN                NaN
#
#   attendance of Rick attendance of Bill attendance of Jane  \
# 0             Absent                NaN                NaN
# 1                NaN            Present             Absent
# 2                NaN                NaN                NaN
#
#   attendance of Kenny attendance of Walton attendance of Isabel  \
# 0                 NaN                  NaN                  NaN
# 1             Present                  NaN                  NaN
# 2                 NaN              Present               Absent
#
#   attendance of Lili
# 0                NaN
# 1                NaN
# 2            Present
