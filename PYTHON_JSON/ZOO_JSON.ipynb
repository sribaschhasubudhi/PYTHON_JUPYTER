# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
zoo_data={{"Chambers":"C1",
          "Primates":{"Monkey":
                      {"Male":1,"Female":4},
                     "Chimpanzee":
                     {"Male":3,"Female":2},
                     "Baboon":
                     {"Male":4,"Female":7}
                     }
            },
        {"Chambers":"C2",
        "Reptiles":{"Python":
                    {"Male":1,"Female":1},
                     "Crocodile":
                     {"Male":3,"Female":5},
                     "Turtle":
                     {"Male":4,"Female":5}
                     }
          },
        {"Chambers":"C3",
        "Felines":{"Tiger":
                   {"Male":1,"Female":3},
                     "Lion":
                     {"Male":2,"Female":2},
                     "Leopards":
                     {"Male":3,"Female":7}}
            }
          }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 zoo_data={{"Chambers":"C1",
#       2           "Primates":{"Monkey":
#       3                       {"Male":1,"Female":4},
#       4                      "Chimpanzee":
#       5                      {"Male":3,"Female":2},
#       6                      "Baboon":
#       7                      {"Male":4,"Female":7}
#       8                      }
#       9             },
#      10         {"Chambers":"C2",
#      11         "Reptiles":{"Python":
#      12                     {"Male":1,"Female":1},
#      13                      "Crocodile":
#      14                      {"Male":3,"Female":5},
#      15                      "Turtle":
#      16                      {"Male":4,"Female":5}
#      17                      }
#      18           },
#      19         {"Chambers":"C3",
# ...

# %%
pd.json_normalize(zoo_data)
# Out:
#   Chambers  Primates.Monkey.Male  Primates.Monkey.Female  \
# 0       C3                     1                       4
#
#    Primates.Chimpanzee.Male  Primates.Chimpanzee.Female  Primates.Baboon.Male  \
# 0                         3                           2                     4
#
#    Primates.Baboon.Female  Reptiles.Python.Male  Reptiles.Python.Female  \
# 0                       7                     1                       1
#
#    Reptiles.Crocodile.Male  Reptiles.Crocodile.Female  Reptiles.Turtle.Male  \
# 0                        3                          5                     4
#
#    Reptiles.Turtle.Female  Felines.Tiger.Male  Felines.Tiger.Female  \
# 0                       5                   1                     3
#
#    Felines.Lion.Male  Felines.Lion.Female  Felines.Leopards.Male  \
# 0                  2                    2                      3
#
#    Felines.Leopards.Female
# 0                        7
