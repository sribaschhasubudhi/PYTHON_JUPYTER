# %%
stationary=["Notebooks","Pencils","Pens","Eraser"]
quantity=[4,3,2,1]
student=list(zip(stationary,quantity))
print(student)
print(tuple(student))
# Out:
# [('Notebooks', 4), ('Pencils', 3), ('Pens', 2), ('Eraser', 1)]
# (('Notebooks', 4), ('Pencils', 3), ('Pens', 2), ('Eraser', 1))

# %%
for b,c in student:
    print(f"{c} {b} needed")
# Out:
# 4 Notebooks needed
# 3 Pencils needed
# 2 Pens needed
# 1 Eraser needed

# %%
student2=dict(student)
print(student2)
for i in student2.values():
    print(i)
# Out:
# {'Notebooks': 4, 'Pencils': 3, 'Pens': 2, 'Eraser': 1}
# 4
# 3
# 2
# 1

# %%
materials,qu=zip(*student)
print(materials)
print(qu)
# Out:
# ('Notebooks', 'Pencils', 'Pens', 'Eraser')
# (4, 3, 2, 1)
