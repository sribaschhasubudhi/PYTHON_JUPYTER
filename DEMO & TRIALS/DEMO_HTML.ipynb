# %% [markdown]
# # PANDAS HTML DEMO

# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
html=pd.read_html("https://www.boldtuesday.com/pages/alphabetical-list-of-all-countries-and-capitals-shown-on-list-of-countries-poster?srsltid=AfmBOor6kFPabteXsFPr_uxBNuM44A3Ujv7IetVJZzQbY-UHGQz_k7Vn")
# table having list of countriea and its capital
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 html=pd.read_html("https://www.boldtuesday.com/pages/alphabetical-list-of-all-countries-and-capitals-shown-on-list-of-countries-poster?srsltid=AfmBOor6kFPabteXsFPr_uxBNuM44A3Ujv7IetVJZzQbY-UHGQz_k7Vn")
#       2 # table having list of countriea and its capital
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...

# %%
html[1]
# Out:
#                        0                    1
# 0       B (17 countries)     B (17 countries)
# 1           BAHAMAS, THE               NASSAU
# 2                BAHRAIN               MANAMA
# 3             BANGLADESH                DHAKA
# 4               BARBADOS           BRIDGETOWN
# 5                BELARUS                MINSK
# 6                BELGIUM             BRUSSELS
# 7                 BELIZE             BELMOPAN
# 8                  BENIN           PORTO-NOVO
# 9                 BHUTAN              THIMPHU
# 10               BOLIVIA        SUCRE, LA PAZ
# 11  BOSNIA & HERZEGOVINA             SARAJEVO
# 12              BOTSWANA             GABORONE
# 13                BRAZIL             BRASILIA
# 14                BRUNEI  BANDAR SERI BEGAWAN
# 15              BULGARIA                SOFIA
# 16          BURKINA FASO          OUAGADOUGOU
# 17               BURUNDI    GITEGA, BUJUMBURA

# %%
html2=pd.read_html("https://www.boldtuesday.com/pages/alphabetical-list-of-all-countries-and-capitals-shown-on-list-of-countries-poster?srsltid=AfmBOor6kFPabteXsFPr_uxBNuM44A3Ujv7IetVJZzQbY-UHGQz_k7Vn",match="INDIA",index_col=0)
print(html2)
# table containing contries starting with "I"
# Out:
# [                               1
# 0
# I (8 countries)  I (8 countries)
# ICELAND                REYKJAVIK
# INDIA                  NEW DELHI
# INDONESIA                JAKARTA
# IRAN                      TEHRAN
# IRAQ                     BAGHDAD
# IRELAND                   DUBLIN
# ISRAEL                 JERUSALEM
# ITALY                       ROME]

# %%
type(html2)
# Out:
# list

# %%
html3=pd.read_html("https://afd.calpoly.edu/web/sample-tables")

# %%
html3[-1]
# Out:
#    NAME OF SYSTEM OR PORTAL CHANNEL  \
# 0              Personal Information
# 1              Personal Information
# 2              Personal Information
# 3              Personal Information
# 4               Group Leave Balance
# 5                Leave/CTO Balances
# 6               Faculty Course Info
# 7               Faculty Course Info
# 8               Faculty Course Info
# 9               Faculty Course Info
# 10              Faculty Course Info
# 11              Faculty Course Info
# 12              Enrollment Planning
# 13                      Student Pay
# 14                         PolyData
# 15                         PolyData
# 16                      PolyProfile
# 17                      PolyProfile
# 18                      PolyProfile
#
#                      NAME OF SYSTEM OR ACTIVITY STATUS DURING OUTAGE  \
# 0                                     Addresses            View Only
# 1                                         Names            View Only
# ...

# %%
id_data={"ID":[1023,1482,1738,1936,1007],
         "Name":["Jake","Steve","Kalie","Harry","Jenny"]}
id_df=pd.DataFrame(id_data)
id_df
# Out:
#      ID   Name
# 0  1023   Jake
# 1  1482  Steve
# 2  1738  Kalie
# 3  1936  Harry
# 4  1007  Jenny

# %%
html4=id_df.to_html("FILES_JUPYTER/ID.html",index=False)

# %%
print(pd.read_html("FILES_JUPYTER/ID.html",index_col="ID"))
ID_rowdf=pd.read_html("FILES_JUPYTER/ID.html",index_col="ID")
# Out:
# [       Name
# ID
# 1023   Jake
# 1482  Steve
# 1738  Kalie
# 1936  Harry
# 1007  Jenny]

# %%
print(type(ID_rowdf))
# Out:
# <class 'list'>

# %%
'''html4_1=id_df.to_html("FILES_JUPYTER/ID.html",index=False,justify="center")
print(pd.read_html("FILES_JUPYTER/ID.html",index_col="ID"))
# HTML text has been aligned to center'''
# Out:
# 'html4_1=id_df.to_html("FILES_JUPYTER/ID.html",index=False,justify="center")\nprint(pd.read_html("FILES_JUPYTER/ID.html",index_col="ID"))\n# HTML text has been aligned to center'

# %%
html5=pd.read_html("https://en.wikipedia.org/wiki/The_Conjuring_Universe")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 html5=pd.read_html("https://en.wikipedia.org/wiki/The_Conjuring_Universe")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
# ...
